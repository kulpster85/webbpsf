# %% [markdown]
# # Tutorial for WebbPSF: Computing Simulated Point Spread Functions for JWST

# %% [markdown]
# This tutorial will walk you through the basics of using the WebbPSF package to calculate PSFs for JWST. This focuses on the command-line/programming interface rather than the graphical interface. Let's begin.
#
# First, we set up the notebook to display plots inline, and to plot images with the origin in the lower left.

# %%
# Uncomment these lines to install dependencies
# !pip install webbpsf
# !pip install astropy
# !pip install sphinx --upgrade
# !pip install wget
# !pip install tarfile
# Out:
# Requirement already satisfied: webbpsf in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (1.11.4)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (3.7.1)
# Requirement already satisfied: astropy>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (6.1.1)
# Requirement already satisfied: photutils>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (1.13.0)
# Requirement already satisfied: poppy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (1.1.1)
# Requirement already satisfied: pysiaf>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (0.22.0)
# Requirement already satisfied: synphot>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (1.4.0)
# Requirement already satisfied: astroquery>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from webbpsf) (0.4.7)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.1.0->webbpsf) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.5.27.0.30.8 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.1.0->webbpsf) (0.2024.7.8.0.31.19)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.1.0->webbpsf) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.1.0->webbpsf) (24.1)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.10/dist-packages (from astroquery>=0.4.6->webbpsf) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.8 in /usr/local/lib/python3.10/dist-packages (from astroquery>=0.4.6->webbpsf) (4.12.3)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.10/dist-packages (from astroquery>=0.4.6->webbpsf) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/lib/python3/dist-packages (from astroquery>=0.4.6->webbpsf) (23.5.0)
# Requirement already satisfied: pyvo>=1.1 in /usr/local/lib/python3.10/dist-packages (from astroquery>=0.4.6->webbpsf) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.0->webbpsf) (2.8.2)
# Requirement already satisfied: lxml>=4.6.4 in /usr/local/lib/python3.10/dist-packages (from pysiaf>=0.19.1->webbpsf) (4.9.4)
# Requirement already satisfied: numpydoc>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pysiaf>=0.19.1->webbpsf) (1.7.0)
# Requirement already satisfied: openpyxl>=3.0.9 in /usr/local/lib/python3.10/dist-packages (from pysiaf>=0.19.1->webbpsf) (3.1.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.8->astroquery>=0.4.6->webbpsf) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery>=0.4.6->webbpsf) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=0.999->astroquery>=0.4.6->webbpsf) (0.5.1)
# Requirement already satisfied: sphinx>=6 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (7.3.7)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (0.9.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (2.0.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.0.9->pysiaf>=0.19.1->webbpsf) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery>=0.4.6->webbpsf) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery>=0.4.6->webbpsf) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery>=0.4.6->webbpsf) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->astroquery>=0.4.6->webbpsf) (2024.7.4)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (1.0.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (3.1.4)
# Requirement already satisfied: Pygments>=2.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (2.16.1)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (0.18.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (1.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->sphinx>=6->numpydoc>=1.1.0->pysiaf>=0.19.1->webbpsf) (2.1.5)
# Requirement already satisfied: astropy in /usr/local/lib/python3.10/dist-packages (6.1.1)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from astropy) (1.25.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.5.27.0.30.8 in /usr/local/lib/python3.10/dist-packages (from astropy) (0.2024.7.8.0.31.19)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy) (24.1)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.10/dist-packages (7.3.7)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx) (1.0.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from sphinx) (3.1.4)
# Requirement already satisfied: Pygments>=2.14 in /usr/local/lib/python3.10/dist-packages (from sphinx) (2.16.1)
# Requirement already satisfied: docutils<0.22,>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from sphinx) (0.18.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.10/dist-packages (from sphinx) (2.15.0)
# Requirement already satisfied: alabaster~=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from sphinx) (2.31.0)
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.10/dist-packages (from sphinx) (24.1)
# Requirement already satisfied: tomli>=2 in /usr/local/lib/python3.10/dist-packages (from sphinx) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->sphinx) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->sphinx) (2024.7.4)
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)
# ERROR: Could not find a version that satisfies the requirement tarfile (from versions: none)
# ERROR: No matching distribution found for tarfile

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['image.origin'] = 'lower'
import wget
import tarfile

# %%
url = 'https://stsci.box.com/shared/static/qxpiaxsjwo15ml6m4pkhtk36c9jgj70k.gz'
filename = 'webbpsf-data.tar.gz'
wget.download(url, filename)

# Extract the archive
with tarfile.open(filename, 'r:gz') as tar:
    tar.extractall()
# %env WEBBPSF_PATH=/content/webbpsf-data/
# Out:
# env: WEBBPSF_PATH=/content/webbpsf-data/

# %% [markdown]
# ## Getting Started

# %% [markdown]
# We assume you have already installed webbpsf from PyPI or some other source, and can successfully import it.

# %%
import webbpsf

# %% [markdown]
# ## First PSFs

# %% [markdown]
# Now let's get started with some calculations. WebbPSF provides a set of five objects corresponding to JWST's four instruments plus the FGS. To calculate a PSF, we first instantiate one of these:

# %%
nc = webbpsf.NIRCam()

# %% [markdown]
# In the case of NIRCam, which has multiple detectors, the default is set to `NRCA1` for now.  The default filter is F200W.

# %% [markdown]
# And then call its ``calcPSF`` function.
#
# The returned result is a fits HDUList object containing both the image data and its associated metadata in the header.

# %%
psf = nc.calc_psf(nlambda=5, fov_arcsec=2)

# %% [markdown]
# We can display the PSF that we have just created:

# %%
webbpsf.display_psf(psf)

# %% [markdown]
# The default behavior of WebbPSF is to compute *oversampled* PSFs (i.e. sampled more finely than the detector pixel scale) by a factor of 4. However, it also produces a version of the same PSF that has been downsampled onto the detector scale. This is saved as an image extension in the same result file.
#
# Since the PSFs are returned in regular FITS HDUList objects, we can examine, save, and generally manipulate them like any other HDUList. Let's look at the different extensions:

# %%
psf.info()
# Out:
# Filename: (No file associated with this HDUList)
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  OVERSAMP      1 PrimaryHDU     108   (256, 256)   float64
#   1  DET_SAMP      1 ImageHDU       110   (64, 64)   float64
#   2  OVERDIST      1 ImageHDU       162   (256, 256)   float64
#   3  DET_DIST      1 ImageHDU       163   (64, 64)   float64

# %%
for ext in [0, 1]:
    print(f"Extenstion {ext} has oversampling factor = ", psf[ext].header['OVERSAMP'],
          f"\tPixelscale = {psf[ext].header['PIXELSCL']:.4f} arcsec/pix")
# Out:
# Extenstion 0 has oversampling factor =  4 	Pixelscale = 0.0078 arcsec/pix
# Extenstion 1 has oversampling factor =  1 	Pixelscale = 0.0312 arcsec/pix

# %% [markdown]
# Extension 0, the primary image, is the oversampled computed PSF. Extension 1 has been binned down to the detector scale.
#
# The display functions in webbpsf allow you to specify an extension, either by index number or by extension name. Let's display the detector-sampled PSF from extension 1.

# %%
webbpsf.display_psf(psf,ext='DET_SAMP')

# %% [markdown]
# ### Specifying instrument parameters

# %% [markdown]
# Instruments have properties corresponding to their configurable options, typically the bandpass filter and optional image plane and pupil plane masks.

# %%
nc.filter='F444W'
psf444 = nc.calc_psf(fov_arcsec=2)
webbpsf.display_psf(psf444)

# %%
nc.filter='F212N'
psf212 = nc.calc_psf(fov_arcsec=2)
webbpsf.display_psf(psf212)

# %% [markdown]
# We can also specify different locations within an instrument. This will generally result in small but measurable differences.

# %%
nc.detector='NRCB3'

nc.detector_position = (500, 1600)

psf212_nrcb3 = nc.calc_psf(fov_arcsec=2)
webbpsf.display_psf(psf212_nrcb3)

# %% [markdown]
# ## A coronagraphic example

# %% [markdown]
# More complicated instrumental configurations are available by setting the instrument’s attributes. For instance, one can create an instance of MIRI and configure it for coronagraphic observations, as follows. This also shows off the ability to display the intermediate optical planes during a calculation:

# %%
# optional: make the plot bigger so we can see everything more easily
matplotlib.pyplot.figure(figsize=(14, 8))

miri = webbpsf.MIRI()
miri.filter = 'F1065C'
miri.image_mask = 'FQPM1065'
miri.pupil_mask = 'MASKFQPM'
miri_coron = miri.calc_psf(display=True)

# %% [markdown]
# ##  More Examples
#
# Here are some other example calculations taken from elsewhere in the ``webbpsf`` documentation.
#
# Some of these differ cosmetically from the code there: this notebook contains some extra function calls to set an aesthetically pleasing size for each plot, and to save the outputs to PNGs. These lines are left out of the example docs HTML page just to streamline it a bit.

# %%
# Iterate over all instruments, calculating one example PSF for each
insts = ['NIRCam','NIRCam','NIRSpec','NIRISS', 'MIRI', 'FGS']
filts = ['F210M', 'F444W', 'F110W', 'F380M', 'F1000W', 'FGS']

psfs = {}
for i, (instname, filt) in enumerate(zip(insts, filts)):
    inst = webbpsf.instrument(instname)
    inst.filter = filt
    psf = inst.calc_psf(fov_arcsec=5.0)
    psfs[instname+filt] = psf
    print(inst)
# Out:
# <JWST: NIRCam>
# <JWST: NIRCam>
# <JWST: NIRSpec>
# <JWST: NIRISS>
# <JWST: MIRI>
# <JWST: FGS>

# %%
# Now make a nice plot of them
plt.figure(figsize=(16*0.75,3*0.75))
plt.subplots_adjust(wspace=0.05, bottom=0.05, top=0.9)
for i, (instname, filt) in enumerate(zip(insts, filts)):
    ax = plt.subplot(1,6,1+i)
    webbpsf.display_psf(psfs[instname+filt], colorbar=False, title=instname+" "+filt, vmax=0.03, imagecrop=3, ext=1)
    if i > 0:
        ax.yaxis.set_visible(False)
plt.tight_layout()
plt.savefig('fig_instrument_comparison.png', dpi=150)

# %%
# Example plot of F200W calculation
plt.figure(figsize=(10,5))
nc = webbpsf.NIRCam()
nc.filter =  'F200W'
nc.calc_psf(display=True)
plt.savefig('fig1_nircam_f200w.png', dpi=120)

# %% [markdown]
# ## Displaying a PSF as an image and as an encircled energy plot

# %%
#create a NIRCam instance and calculate a PSF for F210M
nircam = webbpsf.NIRCam()
nircam.filter = 'F210M'
psf210 = nircam.calc_psf()

# display the PSF and plot the encircled energy
plt.figure(figsize=(9,5))
plt.subplot(1,2,1)
webbpsf.display_psf(psf210, colorbar_orientation='horizontal')
axis2 = plt.subplot(1,2,2)
webbpsf.display_ee(psf210, ax=axis2)

psf210.writeto('nircam_F210M.fits', overwrite=True)
plt.savefig('fig_example_plot_nircam_f210m.png')
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# WARNING:astroquery:VerifyWarning: Card is too long, comment will be truncated.

# %% [markdown]
# ## Logging and More Verbose Output

# %% [markdown]
# WebbPSF produces various log messages while it works, using Python's built-in logging mechanism. In order to see them, we need to set up a log handler that will display them on the screen. This is done using the ``setup_logging`` function.

# %%
webbpsf.setup_logging()
# Out:
# WebbPSF log messages of level INFO and above will be shown.
# WebbPSF log outputs will be directed to the screen.

# %% [markdown]
# We can also choose to save log outputs to a file, if that's desired.

# %%
webbpsf.setup_logging(filename='my_log.txt')
# Out:
# WebbPSF log messages of level INFO and above will be shown.
# WebbPSF log outputs will be directed to the screen.
# WebbPSF log outputs will also be saved to file my_log.txt

# %%
psf = nc.calc_psf(nlambda=5, fov_arcsec=2)
# Out:
# [  poppy] No source spectrum supplied, therefore defaulting to 5700 K blackbody
# [  poppy] Computing wavelength weights using synthetic photometry for F200W...
# [  poppy] PSF calc using fov_arcsec = 2.000000, oversample = 4, number of wavelengths = 5
# [webbpsf] Creating optical system model:
# [  poppy] Initialized OpticalSystem: JWST+NIRCam
# [  poppy] JWST Entrance Pupil: Loaded amplitude transmission from /content/webbpsf-data/jwst_pupil_RevW_npix1024.fits.gz
# [  poppy] JWST Entrance Pupil: Loaded OPD from /content/webbpsf-data/JWST_OTE_OPD_cycle1_example_2022-07-30.fits
# [webbpsf] Loading field dependent model parameters from /content/webbpsf-data/NIRCam/OPD/field_dep_table_nircam.fits
# [webbpsf] Calculating field-dependent OTE OPD at v2 = 2.010 arcmin, v3 = -8.792 arcmin
# [  poppy] Added pupil plane: JWST Entrance Pupil
# [  poppy] Added coordinate inversion plane: OTE exit pupil
# [  poppy] Added pupil plane: NIRCamSWA internal WFE at V2V3=(2.01,-8.79)', near ISIM41
# [  poppy] Added detector with pixelscale=0.03122585 and oversampling=4: NIRCam detector
# [  poppy] Calculating PSF with 5 wavelengths
# [  poppy]  Propagating wavelength = 1.7913e-06 m
# [webbpsf]   Applying OPD focus adjustment based on NIRCam focus vs wavelength model
# [webbpsf]   Modified focus from 2.12 to 1.7912993987975956 um: -31.958 nm wfe
# [webbpsf]   Resulting OPD has 26.800 nm rms
# [  poppy]  Propagating wavelength = 1.89162e-06 m
# [webbpsf]   Applying OPD focus adjustment based on NIRCam focus vs wavelength model
# [webbpsf]   Modified focus from 2.12 to 1.8916232464929863 um: -25.539 nm wfe
# [webbpsf]   Resulting OPD has 25.727 nm rms
# [  poppy]  Propagating wavelength = 1.99195e-06 m
# [webbpsf]   Applying OPD focus adjustment based on NIRCam focus vs wavelength model
# [webbpsf]   Modified focus from 2.12 to 1.991947094188377 um: -16.702 nm wfe
# [webbpsf]   Resulting OPD has 26.817 nm rms
# [  poppy]  Propagating wavelength = 2.09227e-06 m
# [webbpsf]   Applying OPD focus adjustment based on NIRCam focus vs wavelength model
# [webbpsf]   Modified focus from 2.12 to 2.0922709418837675 um: -4.176 nm wfe
# [webbpsf]   Resulting OPD has 32.677 nm rms
# [  poppy]  Propagating wavelength = 2.19259e-06 m
# [webbpsf]   Applying OPD focus adjustment based on NIRCam focus vs wavelength model
# [webbpsf]   Modified focus from 2.12 to 2.192594789579158 um: 12.150 nm wfe
# [webbpsf]   Resulting OPD has 44.646 nm rms
# [  poppy]   Calculation completed in 1.354 s
# [  poppy] PSF Calculation completed.
# [webbpsf] Calculating jitter using gaussian
# [  poppy] Calculating jitter using gaussian
# [  poppy] Jitter: Convolving with Gaussian with sigma=0.001 arcsec
# [  poppy]         resulting image peak drops to 1.000 of its previous value
# [webbpsf] Detector charge diffusion: Convolving with Gaussian with sigma=0.006 arcsec
# [  poppy]  Adding extension with image downsampled to detector pixel scale.
# [  poppy]  Downsampling to detector pixel scale, by 4
# [  poppy]  Downsampling to detector pixel scale, by 4
# [webbpsf] Detector IPC: NIRCam NRCA1 (added)
# [webbpsf] Detector IPC: NIRCam NRCA1 (added)

# %% [markdown]
# As you can see, the log output can be fairly verbose. This is often helpful in terms of understanding what's going on.
#
# If you no longer want this level of verbosity, you can turn off display of informational messages:

# %%
webbpsf.setup_logging('ERROR')
# Out:
# WebbPSF log messages of level ERROR and above will be shown.
# WebbPSF log outputs will be directed to the screen.

# %% [markdown]
# ## Jupyter Notebook Widget Interface

# %% [markdown]
# WebbPSF includes an interactive Jupyter notebook interface, which enables quick exploration of PSFs from changing some of the basic options such as filters and image or pupil masks. More complicated calculations need the Python API, but this can be useful for quick calculations.

# %%
#webbpsf.show_notebook_interface('nircam')
